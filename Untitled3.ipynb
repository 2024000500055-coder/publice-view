# %% [markdown]
# <a href="https://colab.research.google.com/github/2024000500055-coder/publice-view/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BankAccount:
    def __init__(self, account_holder, account_number, balance=0):
        self.account_holder = account_holder
        self.account_number = account_number
        self.balance = balance
        self.transactions = []

    def deposit(self, amount):
        self.balance += amount
        self.transactions.append(f"Deposited: {amount}")
        print(f"{amount} deposited successfully.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Error: Insufficient balance!")
        else:
            self.balance -= amount
            self.transactions.append(f"Withdrawn: {amount}")
            print(f"{amount} withdrawn successfully.")

    def get_balance(self):
        print(f"Current Balance: {self.balance}")

    def transaction_history(self):
        print("Transaction History:")
        for t in self.transactions:
            print(t)


acc1 = BankAccount("Refat", "1001")
acc2 = BankAccount("Rahim", "1002")

acc1.deposit(1000)
acc1.withdraw(300)
acc1.deposit(500)
acc1.get_balance()
acc1.transaction_history()

print()

acc2.deposit(2000)
acc2.withdraw(500)
acc2.withdraw(200)
acc2.get_balance()
acc2.transaction_history()
